# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/Users/yniyunj/Desktop/AI/250808-GCOO/data/gct_20250824_211810/mid/gct_df10.csv')
df1
# Out:
#             lat         lng  bicycle_id  region_id  is_activated  battery  \
# 0     37.570851  126.983391        3353        955          True       59
# 1     37.546321  127.101217        6680        446          True       33
# 2     37.552868  127.090260        6680        446          True      100
# 3     37.553531  127.089977        6680        446          True      100
# 4     37.570279  127.086240        6680        446          True      100
# ...         ...         ...         ...        ...           ...      ...
# 8122  37.507132  127.095595      120722        524          True       47
# 8123  37.507253  127.095246      120722        524          True       47
# 8124  37.507074  127.095555      120722        524          True       47
# 8125  37.507304  127.095355      120722        524          True       47
# 8126  37.511385  127.087141      120722        524          True       45
#
#      gcooter_status  is_discount_scooter  model_info_id  \
# ...
